# %%
import pandas as pd
import numpy as np

# %%
# Read data from a CSV file
data = pd.read_csv('penjualan barang.csv')

# %%
data
# Out:
#       Unnamed: 0     tanggal           nama.pembeli nama.barang  kuantum  \
# 0              1  2020-01-02       TOKO HERUNIAWATI       BERAS   1000.0
# 1              2  2020-01-02       TOKO HERUNIAWATI      DAGING    120.0
# 2              3  2020-01-02  TOKO APRILIA SUKRISNI       BERAS   6000.0
# 3              4  2020-01-02  TOKO APRILIA SUKRISNI       MIGOR    408.0
# 4              5  2020-01-02  TOKO APRILIA SUKRISNI      TEPUNG    140.0
# ...          ...         ...                    ...         ...      ...
# 1284        1285  2021-04-08        TOKO MAJU TERUS      DAGING     60.0
# 1285        1286  2021-04-08            TOKO KINORA       BERAS    250.0
# 1286        1287  2021-04-08            TOKO KINORA      TEPUNG    120.0
# 1287        1288  2021-04-09  TOKO BERKAH DUA PUTRA        GULA    100.0
# 1288        1289  2021-04-09  TOKO BERKAH DUA PUTRA      DAGING     80.0
#
#          nominal
# 0      9840000.0
# 1      8400000.0
# 2     62910000.0
# 3      4855200.0
# ...

# %%
unnamed_columns = [col for col in data.columns if 'Unnamed' in col]
unnamed_columns
# Out:
# ['Unnamed: 0']

# %%
new_column_names = {'nama.pembeli': 'nama pembeli', 'nama.barang': 'nama barang'}
data = data.rename(columns=new_column_names)
data
# Out:
#       Unnamed: 0     tanggal           nama pembeli nama barang  kuantum  \
# 0              1  2020-01-02       TOKO HERUNIAWATI       BERAS   1000.0
# 1              2  2020-01-02       TOKO HERUNIAWATI      DAGING    120.0
# 2              3  2020-01-02  TOKO APRILIA SUKRISNI       BERAS   6000.0
# 3              4  2020-01-02  TOKO APRILIA SUKRISNI       MIGOR    408.0
# 4              5  2020-01-02  TOKO APRILIA SUKRISNI      TEPUNG    140.0
# ...          ...         ...                    ...         ...      ...
# 1284        1285  2021-04-08        TOKO MAJU TERUS      DAGING     60.0
# 1285        1286  2021-04-08            TOKO KINORA       BERAS    250.0
# 1286        1287  2021-04-08            TOKO KINORA      TEPUNG    120.0
# 1287        1288  2021-04-09  TOKO BERKAH DUA PUTRA        GULA    100.0
# 1288        1289  2021-04-09  TOKO BERKAH DUA PUTRA      DAGING     80.0
#
#          nominal
# 0      9840000.0
# 1      8400000.0
# 2     62910000.0
# 3      4855200.0
# ...

# %%
selected_columns = ['tanggal', 'nama pembeli', 'nama barang', 'kuantum', 'nominal']
result_data = data.loc[:, selected_columns]
result_data
# Out:
#          tanggal           nama pembeli nama barang  kuantum     nominal
# 0     2020-01-02       TOKO HERUNIAWATI       BERAS   1000.0   9840000.0
# 1     2020-01-02       TOKO HERUNIAWATI      DAGING    120.0   8400000.0
# 2     2020-01-02  TOKO APRILIA SUKRISNI       BERAS   6000.0  62910000.0
# 3     2020-01-02  TOKO APRILIA SUKRISNI       MIGOR    408.0   4855200.0
# 4     2020-01-02  TOKO APRILIA SUKRISNI      TEPUNG    140.0   1162000.0
# ...          ...                    ...         ...      ...         ...
# 1284  2021-04-08        TOKO MAJU TERUS      DAGING     60.0   4389600.0
# 1285  2021-04-08            TOKO KINORA       BERAS    250.0   2718750.0
# 1286  2021-04-08            TOKO KINORA      TEPUNG    120.0   1065120.0
# 1287  2021-04-09  TOKO BERKAH DUA PUTRA        GULA    100.0   1200000.0
# 1288  2021-04-09  TOKO BERKAH DUA PUTRA      DAGING     80.0   5852800.0
#
# [1289 rows x 5 columns]

# %%
data = data.dtypes
data
# Out:
# Unnamed: 0        int64
# tanggal          object
# nama pembeli     object
# nama barang      object
# kuantum         float64
# nominal         float64
# dtype: object

# %%
missing_columns = missing_values.sum()
print("Missing Values per Column:")
print(missing_columns)
# Out:
# Missing Values per Column:
# 0

# %%
# Filter columns to be used
df = data[['nama pembeli', 'nama barang']]

# Mengubah DataFrame menjadi Series (Ini adalah langkah yang salah)
df = pd.DataFrame(df)

# Convert the dataset into a list of transactions
transactions = []
for row in df.itertuples(index=False):
    transaction = [item for item in row if item != '']
    transactions.append(transaction)

# Determine the minimum support threshold values to be tested
min_support_values = [0.01, 0.03, 0.05]

# Helper function to check if an itemset is closed
def is_closed(itemset, closed_itemsets):
    for other_itemset in closed_itemsets:
        if itemset.issubset(other_itemset) and itemset != other_itemset:
            return False
    return True

# Create a file to store the output
output_file = open('output.txt', 'w')

# Loop through the minimum support threshold values
for min_support in min_support_values:
    # Write Minimum Support to the file
    output_file.write(f"Minimum Support {min_support}:\n")
    closed_itemsets = []

    # Count item frequencies
    item_counts = {}
    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1

    # Find frequently occurring items (frequent items)
    frequent_items = {item for item, count in item_counts.items() if count >= len(transactions) * min_support}

    # CT-PRO Algorithm
    for item in frequent_items:
        # Initialize itemset as a set containing only the current item
        itemset = {item}
        # Calculate the support of the itemset
        itemset_support = sum(1 for transaction in transactions if itemset.issubset(set(transaction)))
        # Check if the itemset is closed
        if is_closed(itemset, closed_itemsets):
            # Add the closed itemset to the list
            closed_itemsets.append(itemset)

    # Save "Closed Itemsets" to the file
    output_file.write("\nClosed Itemsets:\n")
    for itemset in closed_itemsets:
        output_file.write("Itemset: {}, Support: {:.4f}\n".format(list(itemset), sum(1 for transaction in transactions if itemset.issubset(set(transaction))) / len(transactions)))

    # Tambahkan baris kosong antara setiap hasil Minimum Support
    output_file.write("\n")

# Tutup file output
output_file.close()
